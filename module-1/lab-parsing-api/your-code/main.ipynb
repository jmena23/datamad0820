# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

# %%
response = urllib.request.urlopen(url)
results = json.load(response)


flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   PI922SA08-Q13                            Sweat à capuche - black
# 1   AD115O0DY-A12  STAN SMITH NEON HEEL SHOES - Baskets basses - ...
# 2   OS322E04A-K12      ONSMARK PANT - Pantalon classique - night sky
# 3   NI122S0AU-Q11  CLUB HOODIE - veste en sweat zippée - black/bl...
# 4   BI112G02T-O11                   ARIZONA - Chaussons - soft brown
# ..            ...                                                ...
# 79  PA412O04Y-O11          ROMA UOMO  - Baskets basses - light brown
# 80  NI122O0HQ-Q11                            T-shirt basique - black
# 81  PI922PA09-K11                                   Polo - dark blue
# 82  TO112O00Z-Q11          ICONIC LONG LACE - Baskets basses - black
# 83  CO412A04J-502  CHUCK TAYLOR ALL STAR HI - Baskets montantes -...
#
#                                                 sizes  \
# 0              [XS, S, M, L, XXL, 3XL, 4XL, 5XL, 6XL]
# 1   [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
# 2   [28x30, 28x32, 28x34, 29x30, 29x32, 29x34, 30x...
# 3                              [XS, S, M, L, XL, XXL]
# 4                    [39, 40, 41, 42, 43, 44, 45, 46]
# ..                                                ...
# 79                   [40, 41, 42, 43, 44, 45, 46, 47]
# 80                             [XS, S, M, L, XL, XXL]
# 81         [XS, S, M, L, XL, XXL, 3XL, 4XL, 5XL, 6XL]
# 82                       [40, 41, 42, 43, 44, 46, 48]
# 83  [35, 36, 36.5, 37, 37.5, 38, 39, 39.5, 40, 41,...
#
#                                               url_key  \
# 0        pier-one-sweat-a-capuche-black-pi922sa08-q13
# 1   adidas-originals-stan-smith-baskets-basses-ad1...
# 2      only-and-sons-onsmark-pant-chino-os322e04a-k12
# 3   nike-sportswear-club-hoodie-veste-en-sweat-zip...
# 4   birkenstock-arizona-mules-soft-brown-bi112g02t...
# ..                                                ...
# 79  pantofola-doro-roma-uomo-baskets-basses-light-...
# 80  nike-sportswear-t-shirt-basique-black-ni122o0h...
# 81              pier-one-polo-dark-blue-pi922pa09-k11
# 82  tommy-hilfiger-iconic-long-lace-baskets-basses...
# 83      converse-baskets-montantes-bleu-co412a04j-502
#
#                                                 media        brand_name  \
# 0   [{'path': 'spp-media-p1/54247209cdba392a900e6d...          Pier One
# 1   [{'path': 'spp-media-p1/e5a1f1bb4a773572a034c7...  adidas Originals
# 2   [{'path': 'spp-media-p1/804480cc8c2c344fa0c490...       Only & Sons
# 3   [{'path': 'spp-media-p1/0611750ba83d38ecb781a1...   Nike Sportswear
# 4   [{'path': 'spp-media-p1/233023ddef2c3de9bc1570...       Birkenstock
# ..                                                ...               ...
# 79  [{'path': 'spp-media-p1/037540e750d43d0ebc6c44...   Pantofola d'Oro
# 80  [{'path': 'spp-media-p1/1b8646a33cde38e0abb427...   Nike Sportswear
# 81  [{'path': 'spp-media-p1/00d0c97e7bc2340c9e4dd8...          Pier One
# 82  [{'path': 'spp-media-p1/d2ef0913d3df33da8cfe6e...    Tommy Hilfiger
# 83  [{'path': 'spp-media-p1/752cb0ad396f32b59c9b65...          Converse
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
# 1   [{'key': 'discountRate', 'value': '-25%', 'tra...          shoe
# 2   [{'key': 'discountRate', 'value': 'Jusqu’à -15...      clothing
# 3   [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': '-20%', 'tra...          shoe
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-10%', 'tra...          shoe
# 80  [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 82  [{'key': 'discountRate', 'value': '-10%', 'tra...          shoe
# 83  [{'key': 'discountRate', 'value': '-10%', 'tra...          shoe
#
#    delivery_promises price.original price.promotional  \
# 0                 []        24,99 €           18,69 €
# 1                 []        99,95 €           74,95 €
# 2                 []        34,99 €           29,69 €
# 3                 []        54,95 €           46,65 €
# 4                 []        84,95 €           67,95 €
# ..               ...            ...               ...
# 79                []        99,95 €           89,95 €
# 80                []        24,95 €           18,65 €
# 81                []        19,99 €           16,99 €
# 82                []        59,95 €           53,95 €
# 83                []        69,95 €           62,95 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                         True                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
#                                               outfits
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83  [{'id': '_tvFlJDlTBi', 'url_key': '/outfits/_t...
#
# [84 rows x 18 columns]

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(150):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = urllib.request.urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    print(f"getting page {i} of {total_pages} LIMITADO a 150 páginas", end='\r')

df
# Out:
# getting page 149 of 653 LIMITADO a 150 páginas
#                                                             name  \
# sku
# AD116D008-A11          STAN SMITH - Baskets basses - white/green
# LE226G007-C11  BATWING - T-shirt à manches longues - grey hea...
# AD116D07G-A11  STAN SMITH CF I - Chaussures premiers pas - wh...
# NI114D0CS-A11            COURT BOROUGH  - Baskets basses - white
# AD116D0MP-A11  STAN SMITH - Baskets basses - footwear white/c...
# ...                                                          ...
# GU124D051-K11             ACTIVE SET - Veste sans manches - bleu
# C1784C00J-K11  TANK CORE PLACED LOGO - Accessoire de plage - ...
# HU313G000-J11       SPORT - Sandales de randonnée - mauve/shadow
# HU313G001-K11             SPORT FLOWERS - Sandales - blue nights
# P6823F00U-K11                         Robe en jersey - deep navy
#
#                                                            sizes  \
# sku
# AD116D008-A11           [36, 38, 35 1/2, 36 2/3, 37 1/3, 38 2/3]
# LE226G007-C11                       [6a, 8a, 10a, 12a, 14a, 16a]
# AD116D07G-A11               [19, 20, 21, 22, 23, 24, 25, 26, 27]
# NI114D0CS-A11  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5,...
# AD116D0MP-A11  [36, 38, 40, 35 1/2, 36 2/3, 37 1/3, 38 2/3, 3...
# ...                                                          ...
# GU124D051-K11                                             [3-6m]
# C1784C00J-K11                                           [14-16a]
# HU313G000-J11                                   [28, 30, 33, 36]
# HU313G001-K11                                               [34]
# P6823F00U-K11                                               [6a]
#
#                                                          url_key  \
# sku
# AD116D008-A11  adidas-originals-stan-smith-baskets-basses-bla...
# LE226G007-C11  levisr-batwing-tee-t-shirt-a-manches-longues-l...
# AD116D07G-A11  adidas-originals-stan-smith-cf-i-baskets-basse...
# NI114D0CS-A11  nike-sportswear-court-borough-baskets-basses-n...
# AD116D0MP-A11  adidas-originals-stan-smith-baskets-basses-foo...
# ...                                                          ...
# GU124D051-K11          guess-active-set-short-bleu-gu124d051-k11
# C1784C00J-K11  calvin-klein-swimwear-tank-core-placed-logo-de...
# HU313G000-J11  hummel-sport-sandales-de-randonnee-mauveshadow...
# HU313G001-K11  hummel-sport-flowers-sandales-de-randonnee-blu...
# P6823F00U-K11  petrol-industries-robe-en-jersey-deep-navy-p68...
#
#                                                            media  \
# sku
# AD116D008-A11  [{'path': 'spp-media-p1/6e77790477903cb2943858...
# LE226G007-C11  [{'path': 'spp-media-p1/dd9fded32dde3b17b0486c...
# AD116D07G-A11  [{'path': 'spp-media-p1/ce39b604a97b373bbe8e46...
# NI114D0CS-A11  [{'path': 'spp-media-p1/0b5fec9e420b37099ccfe6...
# AD116D0MP-A11  [{'path': 'spp-media-p1/e35946364032394ea54a0f...
# ...                                                          ...
# GU124D051-K11  [{'path': 'spp-media-p1/9818f942a8403194b1051e...
# C1784C00J-K11  [{'path': 'spp-media-p1/a4888c6b6d753bfebea8c2...
# HU313G000-J11  [{'path': 'spp-media-p1/4ef852e9045b3395a37e5d...
# HU313G001-K11  [{'path': 'spp-media-p1/f2b58fa06fca375eb9b555...
# P6823F00U-K11  [{'path': 'spp-media-p1/b2a467486fbf3e6c8441bb...
#
#                           brand_name  is_premium family_articles  \
# sku
# AD116D008-A11       adidas Originals       False              []
# LE226G007-C11                Levi's®       False              []
# AD116D07G-A11       adidas Originals       False              []
# NI114D0CS-A11        Nike Sportswear       False              []
# AD116D0MP-A11       adidas Originals       False              []
# ...                              ...         ...             ...
# GU124D051-K11                  Guess       False              []
# C1784C00J-K11  Calvin Klein Swimwear       False              []
# HU313G000-J11                 Hummel       False              []
# HU313G001-K11                 Hummel       False              []
# P6823F00U-K11      Petrol Industries       False              []
#
#                                                            flags  \
# sku
# AD116D008-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -30...
# LE226G007-C11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# AD116D07G-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -25...
# NI114D0CS-A11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# AD116D0MP-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -20...
# ...                                                          ...
# GU124D051-K11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# C1784C00J-K11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# HU313G000-J11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# HU313G001-K11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# P6823F00U-K11  [{'key': 'discountRate', 'value': '-20%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# AD116D008-A11          shoe                []        64,95 €
# LE226G007-C11      clothing                []        21,95 €
# AD116D07G-A11          shoe                []        49,95 €
# NI114D0CS-A11          shoe                []        34,95 €
# AD116D0MP-A11          shoe                []        64,95 €
# ...                     ...               ...            ...
# GU124D051-K11      clothing                []        44,95 €
# C1784C00J-K11    beach_wear                []        25,95 €
# HU313G000-J11          shoe                []        39,95 €
# HU313G001-K11          shoe                []        39,95 €
# P6823F00U-K11      clothing                []        49,99 €
#
#               price.promotional  price.has_different_prices  \
# sku
# AD116D008-A11           45,45 €                        True
# LE226G007-C11           16,45 €                        True
# AD116D07G-A11           37,45 €                        True
# NI114D0CS-A11           27,95 €                       False
# AD116D0MP-A11           51,95 €                        True
# ...                         ...                         ...
# GU124D051-K11           35,95 €                       False
# C1784C00J-K11           19,55 €                       False
# HU313G000-J11           31,95 €                       False
# HU313G001-K11           31,95 €                       False
# P6823F00U-K11           39,99 €                       False
#
#                price.has_different_original_prices  \
# sku
# AD116D008-A11                                False
# LE226G007-C11                                False
# AD116D07G-A11                                False
# NI114D0CS-A11                                False
# AD116D0MP-A11                                False
# ...                                            ...
# GU124D051-K11                                False
# C1784C00J-K11                                False
# HU313G000-J11                                False
# HU313G001-K11                                False
# P6823F00U-K11                                False
#
#                price.has_different_promotional_prices  \
# sku
# AD116D008-A11                                    True
# LE226G007-C11                                    True
# AD116D07G-A11                                    True
# NI114D0CS-A11                                   False
# AD116D0MP-A11                                    True
# ...                                               ...
# GU124D051-K11                                   False
# C1784C00J-K11                                   False
# HU313G000-J11                                   False
# HU313G001-K11                                   False
# P6823F00U-K11                                   False
#
#                price.has_discount_on_selected_sizes_only amount condition  \
# sku
# AD116D008-A11                                      False    NaN       NaN
# LE226G007-C11                                      False    NaN       NaN
# AD116D07G-A11                                      False    NaN       NaN
# NI114D0CS-A11                                      False    NaN       NaN
# AD116D0MP-A11                                      False    NaN       NaN
# ...                                                  ...    ...       ...
# GU124D051-K11                                      False    NaN       NaN
# C1784C00J-K11                                      False    NaN       NaN
# HU313G000-J11                                      False    NaN       NaN
# HU313G001-K11                                      False    NaN       NaN
# P6823F00U-K11                                      False    NaN       NaN
#
#               condition_key
# sku
# AD116D008-A11           NaN
# LE226G007-C11           NaN
# AD116D07G-A11           NaN
# NI114D0CS-A11           NaN
# AD116D0MP-A11           NaN
# ...                     ...
# GU124D051-K11           NaN
# C1784C00J-K11           NaN
# HU313G000-J11           NaN
# HU313G001-K11           NaN
# P6823F00U-K11           NaN
#
# [12600 rows x 19 columns]

# %% [markdown]
# # Bonus

# %% [markdown]
# Extract the following information from the data:
#  - The trending brand.
#  - The product(s) with the highest discount.
#  - The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

df.brand_name.value_counts().index[0]
# Out:
# 'Boboli'

# %%
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Scotch & Soda'

# %%
round(sum(df['discount_amount']), 2)
# Out:
# 181010.28

# %%
round(total_disc.sum(), 2)
# Out:
# 181010.28

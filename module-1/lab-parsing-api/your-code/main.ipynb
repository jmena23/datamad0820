# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

# %%
response = urllib.request.urlopen(url)
results = json.load(response)


flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   PI922D01Q-G12                                    Polo - bordeaux
# 1   OS322E04A-K12      ONSMARK PANT - Pantalon classique - night sky
# 2   TO122E04C-Q11  BASIC BRANDED  - Pantalon de survêtement - jet...
# 3   SU222S0T9-K11  LABEL ZIPHOOD - veste en sweat zippée - eclips...
# 4   PO222O03F-G16                 T-shirt basique - evening post red
# ..            ...                                                ...
# 79  PI912C095-Q12                                  Mocassins - black
# 80  JA222Q0QM-Q11               JJEEMIL ROLL NECK - Pullover - black
# 81  PI952H04U-K11                         Mallette - dark blue/beige
# 82  N1242D358-K11  PARIS ST GERMAIN - Article de supporter - midn...
# 83  PI922O0GQ-A12  3 PACK - T-shirt basique - white/black/light grey
#
#                                                 sizes  \
# 0               [XS, S, M, L, XL, XXL, 3XL, 4XL, 6XL]
# 1   [28x30, 28x32, 28x34, 29x30, 29x32, 29x34, 30x...
# 2                                       [S, M, L, XL]
# 3                              [XS, S, M, L, XL, XXL]
# 4                              [XS, S, M, L, XL, XXL]
# ..                                                ...
# 79           [40, 41, 42, 43, 44, 45, 46, 47, 48, 50]
# 80                                 [S, M, L, XL, XXL]
# 81                                         [One Size]
# 82                                 [S, M, L, XL, XXL]
# 83         [XS, S, M, L, XL, XXL, 3XL, 4XL, 5XL, 6XL]
#
#                                               url_key  \
# 0                   pier-one-polo-rouge-pi922d01q-g12
# 1      only-and-sons-onsmark-pant-chino-os322e04a-k12
# 2   tommy-hilfiger-basic-branded-pantalon-de-surve...
# 3   superdry-label-ziphood-veste-en-sweat-zippee-s...
# 4   polo-ralph-lauren-slim-fit-t-shirt-basique-po2...
# ..                                                ...
# 79             pier-one-mocassins-black-pi912c095-q12
# 80  jack-and-jones-jjeemil-roll-neck-pullover-ja22...
# 81  pier-one-sac-ordinateur-dark-bluebeige-pi952h0...
# 82  nike-performance-paris-st-germain-t-shirt-de-s...
# 83  pier-one-3-pack-t-shirt-basique-whiteblackligh...
#
#                                                 media         brand_name  \
# 0   [{'path': 'spp-media-p1/4a58a8800afb3307b80155...           Pier One
# 1   [{'path': 'spp-media-p1/804480cc8c2c344fa0c490...        Only & Sons
# 2   [{'path': 'spp-media-p1/20d98018446137a886d715...     Tommy Hilfiger
# 3   [{'path': 'spp-media-p1/3079de85f31b3795a1a2ed...           Superdry
# 4   [{'path': 'spp-media-p1/59799e7aa000337291b6c2...  Polo Ralph Lauren
# ..                                                ...                ...
# 79  [{'path': 'spp-media-p1/d8edbd42a574319c9b5be6...           Pier One
# 80  [{'path': 'spp-media-p1/709e3c7650603b16b82e77...       Jack & Jones
# 81  [{'path': 'spp-media-p1/7a3b3d9ee3ca327e86c984...           Pier One
# 82  [{'path': 'spp-media-p1/32ed8497216038fe9cc566...   Nike Performance
# 83  [{'path': 'spp-media-p1/b532deea66c43cb988d78d...           Pier One
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4         True              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 1   [{'key': 'discountRate', 'value': 'Jusqu’à -15...      clothing
# 2   [{'key': 'discountRate', 'value': '-45%', 'tra...      clothing
# 3   [{'key': 'discountRate', 'value': 'Jusqu’à -20...      clothing
# 4   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-25%', 'tra...          shoe
# 80  [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-55%', 'tra...   accessoires
# 82  [{'key': 'discountRate', 'value': 'Jusqu’à -18...      clothing
# 83  [{'key': 'discountRate', 'value': '-10%', 'tra...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        14,99 €           12,74 €
# 1                 []        34,99 €           29,69 €
# 2                 []       109,95 €           60,95 €
# 3                 []        79,99 €           63,99 €
# 4                 []        59,95 €           47,95 €
# ..               ...            ...               ...
# 79                []        33,99 €           25,59 €
# 80                []        39,99 €           27,99 €
# 81                []        43,99 €           19,99 €
# 82                []        89,95 €           73,35 €
# 83                []        19,99 €           17,99 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                         True                                False
# 2                        False                                False
# 3                         True                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                        True                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                     True
# 2                                    False
# 3                                     True
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                    True
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only outfits
# 0                                       False     NaN
# 1                                       False     NaN
# 2                                       False     NaN
# 3                                       False     NaN
# 4                                       False     NaN
# ..                                        ...     ...
# 79                                      False     NaN
# 80                                      False     NaN
# 81                                      False     NaN
# 82                                      False     NaN
# 83                                      False     NaN
#
# [84 rows x 18 columns]

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(200):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset={k}&sort=popularity'
    response = urllib.request.urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    print(f"getting page {i} of {total_pages} LIMITADO a 200 páginas", end='\r')

df
# Out:
# getting page 199 of 654 LIMITADO a 200 páginas
#                                                             name  \
# sku
# TO122O02W-Q11  NEW STRETCH TEE C-NECK - T-shirt basique - fla...
# TO122O02W-A11  NEW STRETCH TEE C-NECK - T-shirt basique - cla...
# TOB22D00R-K11   ORIGINAL STRETCH SLIM FIT - Chemise - black iris
# TOB22D00R-K12  ORIGINAL STRETCH SLIM FIT - Chemise - lavender...
# TH342D02B-Q11    SIMPLE DOME - T-shirt à manches longues - black
# ...                                                          ...
# JAM22O064-K11  T-SHIRT GESTREIFTES - T-shirt imprimé - denim ...
# JA222G162-K11                             Jean slim - blue denim
# 21M22T01S-Q11                              Veste d'hiver - black
# OS322E096-Q11          ONSDUKE - Pantalon de survêtement - black
# DH022A013-O11                       CHECK SUIT - Costume - brown
#
#                                                            sizes  \
# sku
# TO122O02W-Q11                             [XS, S, M, L, XL, XXL]
# TO122O02W-A11                             [XS, S, M, L, XL, XXL]
# TOB22D00R-K11                             [XS, S, M, L, XL, XXL]
# TOB22D00R-K12                             [XS, S, M, L, XL, XXL]
# TH342D02B-Q11                             [XS, S, M, L, XL, XXL]
# ...                                                          ...
# JAM22O064-K11                                      [S, M, L, XL]
# JA222G162-K11  [26x30, 26x32, 27x30, 27x32, 27x34, 28x30, 28x...
# 21M22T01S-Q11                                         [M, L, XL]
# OS322E096-Q11                             [XS, S, M, L, XL, XXL]
# DH022A013-O11                       [40, 42, 44, 46, 90, 94, 98]
#
#                                                          url_key  \
# sku
# TO122O02W-Q11  tommy-hilfiger-slim-fit-t-shirt-basique-flag-b...
# TO122O02W-A11  tommy-hilfiger-slim-fit-t-shirt-basique-classi...
# TOB22D00R-K11  tommy-jeans-original-stretch-slim-fit-chemise-...
# TOB22D00R-K12  tommy-jeans-original-stretch-slim-fit-chemise-...
# TH342D02B-Q11  the-north-face-t-shirt-a-manches-longues-black...
# ...                                                          ...
# JAM22O064-K11  jack-and-jones-premium-t-shirt-imprime-denim-b...
# JA222G162-K11  jack-and-jones-jean-slim-blue-denim-ja222g162-k11
# 21M22T01S-Q11                mo-veste-dhiver-black-21m22t01s-q11
# OS322E096-Q11  only-and-sons-onsduke-pantalon-de-survetement-...
# DH022A013-O11  isaac-dewhirst-check-suit-costume-brown-dh022a...
#
#                                                            media  \
# sku
# TO122O02W-Q11  [{'path': 'spp-media-p1/80cd0d1ad7343fcfb2cdd4...
# TO122O02W-A11  [{'path': 'spp-media-p1/3e1fba3771b93576960dad...
# TOB22D00R-K11  [{'path': 'spp-media-p1/ff32f866097d31a3bbf2a0...
# TOB22D00R-K12  [{'path': 'spp-media-p1/a3ed6630e59f3ec8995831...
# TH342D02B-Q11  [{'path': 'spp-media-p1/5561a33bd99a3fec877c99...
# ...                                                          ...
# JAM22O064-K11  [{'path': 'spp-media-p1/80726f294c4d333db19875...
# JA222G162-K11  [{'path': 'spp-media-p1/b87916c850423737b4a713...
# 21M22T01S-Q11  [{'path': 'spp-media-p1/d1852933c4d33f1590e32f...
# OS322E096-Q11  [{'path': 'spp-media-p1/077429e21cea3fedbb75f6...
# DH022A013-O11  [{'path': 'spp-media-p1/907e192bac3e3e98ab8401...
#
#                          brand_name  is_premium family_articles  \
# sku
# TO122O02W-Q11        Tommy Hilfiger       False              []
# TO122O02W-A11        Tommy Hilfiger       False              []
# TOB22D00R-K11           Tommy Jeans       False              []
# TOB22D00R-K12           Tommy Jeans       False              []
# TH342D02B-Q11        The North Face       False              []
# ...                             ...         ...             ...
# JAM22O064-K11  Jack & Jones PREMIUM       False              []
# JA222G162-K11          Jack & Jones       False              []
# 21M22T01S-Q11                    Mo       False              []
# OS322E096-Q11           Only & Sons       False              []
# DH022A013-O11        Isaac Dewhirst       False              []
#
#                                                            flags  \
# sku
# TO122O02W-Q11  [{'key': 'discountRate', 'value': '-15%', 'tra...
# TO122O02W-A11  [{'key': 'discountRate', 'value': '-15%', 'tra...
# TOB22D00R-K11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# TOB22D00R-K12  [{'key': 'discountRate', 'value': '-25%', 'tra...
# TH342D02B-Q11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# ...                                                          ...
# JAM22O064-K11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# JA222G162-K11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# 21M22T01S-Q11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# OS322E096-Q11  [{'key': 'discountRate', 'value': '-15%', 'tra...
# DH022A013-O11  [{'key': 'discountRate', 'value': '-40%', 'tra...
#
#               product_group delivery_promises  ... price.promotional  \
# sku                                            ...
# TO122O02W-Q11      clothing                []  ...           25,45 €
# TO122O02W-A11      clothing                []  ...           25,45 €
# TOB22D00R-K11      clothing                []  ...           48,95 €
# TOB22D00R-K12      clothing                []  ...           52,45 €
# TH342D02B-Q11      clothing                []  ...           24,45 €
# ...                     ...               ...  ...               ...
# JAM22O064-K11      clothing                []  ...           17,49 €
# JA222G162-K11      clothing                []  ...           48,99 €
# 21M22T01S-Q11      clothing                []  ...          167,96 €
# OS322E096-Q11      clothing                []  ...           33,99 €
# DH022A013-O11      clothing                []  ...           59,95 €
#
#               price.has_different_prices  price.has_different_original_prices  \
# sku
# TO122O02W-Q11                      False                                False
# TO122O02W-A11                      False                                False
# TOB22D00R-K11                      False                                False
# TOB22D00R-K12                      False                                False
# TH342D02B-Q11                      False                                False
# ...                                  ...                                  ...
# JAM22O064-K11                      False                                False
# JA222G162-K11                      False                                False
# 21M22T01S-Q11                      False                                False
# OS322E096-Q11                      False                                False
# DH022A013-O11                      False                                False
#
#                price.has_different_promotional_prices  \
# sku
# TO122O02W-Q11                                   False
# TO122O02W-A11                                   False
# TOB22D00R-K11                                   False
# TOB22D00R-K12                                   False
# TH342D02B-Q11                                   False
# ...                                               ...
# JAM22O064-K11                                   False
# JA222G162-K11                                   False
# 21M22T01S-Q11                                   False
# OS322E096-Q11                                   False
# DH022A013-O11                                   False
#
#                price.has_discount_on_selected_sizes_only  outfits amount  \
# sku
# TO122O02W-Q11                                      False      NaN    NaN
# TO122O02W-A11                                      False      NaN    NaN
# TOB22D00R-K11                                      False      NaN    NaN
# TOB22D00R-K12                                      False      NaN    NaN
# TH342D02B-Q11                                      False      NaN    NaN
# ...                                                  ...      ...    ...
# JAM22O064-K11                                      False      NaN    NaN
# JA222G162-K11                                      False      NaN    NaN
# 21M22T01S-Q11                                      False      NaN    NaN
# OS322E096-Q11                                      False      NaN    NaN
# DH022A013-O11                                      False      NaN    NaN
#
#               price.base_price condition condition_key
# sku
# TO122O02W-Q11              NaN       NaN           NaN
# TO122O02W-A11              NaN       NaN           NaN
# TOB22D00R-K11              NaN       NaN           NaN
# TOB22D00R-K12              NaN       NaN           NaN
# TH342D02B-Q11              NaN       NaN           NaN
# ...                        ...       ...           ...
# JAM22O064-K11              NaN       NaN           NaN
# JA222G162-K11              NaN       NaN           NaN
# 21M22T01S-Q11              NaN       NaN           NaN
# OS322E096-Q11              NaN       NaN           NaN
# DH022A013-O11              NaN       NaN           NaN
#
# [16800 rows x 21 columns]

# %% [markdown]
# # Bonus

# %% [markdown]
# Extract the following information from the data:
#  - The trending brand.
#  - The product(s) with the highest discount.
#  - The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

df.brand_name.value_counts().index[0]
# Out:
# 'Jack & Jones'

# %%
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Puma'

# %%
round(sum(df['discount_amount']), 2)
# Out:
# 365034.03

# %%
round(total_disc.sum(), 2)
# Out:
# 365034.03
